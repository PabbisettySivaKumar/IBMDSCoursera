# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://qmm86575:b1t%2Bqf9vsl0h444j@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: qmm86575@BLUDB'

# %%
# %sql SELECT * FROM SYSCAT.TABLES WHERE TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('QMM86575', 'SCHOOLS', 'QMM86575', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2020, 7, 9, 17, 3, 57, 459856), datetime.datetime(2020, 7, 9, 17, 3, 57, 459856), datetime.datetime(2020, 7, 9, 17, 3, 57, 459856), datetime.datetime(2020, 7, 9, 17, 5, 42, 257614), 78, 7, 1984, 566, 15, 0, 16, -1, -1, -1, 0, 'qmm86575space1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 844, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2020, 7, 9, 17, 3, 57, 459856), 0, ' ', None, None, 'N', 'QMM86575', ' ', ' ', ' ', datetime.date(2020, 7, 9), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql SELECT COUNT(*) FROM SYSCAT.COLUMNS WHERE TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('78'),)]

# %%
# %sql SELECT TYPENAME, COLNAME, LENGTH FROM SYSCAT.COLUMNS WHERE TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('INTEGER', 'School_ID', 4),
#  ('VARCHAR', 'NAME_OF_SCHOOL', 65),
#  ('VARCHAR', 'Elementary, Middle, or High School', 2),
#  ('VARCHAR', 'Street_Address', 30),
#  ('VARCHAR', 'City', 7),
#  ('VARCHAR', 'State', 2),
#  ('INTEGER', 'ZIP_Code', 4),
#  ('VARCHAR', 'Phone_Number', 14),
#  ('VARCHAR', 'Link', 78),
#  ('VARCHAR', 'Network_Manager', 40),
#  ('VARCHAR', 'Collaborative_Name', 34),
#  ('VARCHAR', 'Adequate_Yearly_Progress_Made_', 3),
#  ('VARCHAR', 'Track_Schedule', 12),
#  ('VARCHAR', 'CPS_Performance_Policy_Status', 16),
#  ('VARCHAR', 'CPS_Performance_Policy_Level', 15),
#  ('VARCHAR', 'HEALTHY_SCHOOL_CERTIFIED', 3),
#  ('VARCHAR', 'Safety_Icon', 11),
#  ('SMALLINT', 'SAFETY_SCORE', 2),
#  ('VARCHAR', 'Family_Involvement_Icon', 11),
#  ('VARCHAR', 'Family_Involvement_Score', 3),
#  ('VARCHAR', 'Environment_Icon', 11),
#  ('SMALLINT', 'Environment_Score', 2),
# ...

# %%
# %sql SELECT * FROM SYSCAT.COLUMNS WHERE TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('QMM86575', 'SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 566, '610543', '609674', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('QMM86575', 'SCHOOLS', 'NAME_OF_SCHOOL', 1, 'SYSIBM  ', 'VARCHAR', 65, 0, 'OCTETS', 65, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'Woodlawn Community Elementary Sch'", "'Abraham Lincoln Elementary School'", 41, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 36, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
##%sql SELECT * FROM SCHOOLS

# %%
# %sql SELECT COUNT(*) FROM SCHOOLS WHERE "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('462'),)]

# %%
# %sql SELECT MAX(SAFETY_SCORE) FROM SCHOOLS
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(99,)]

# %%
# %sql SELECT NAME_OF_SCHOOL, SAFETY_SCORE FROM SCHOOLS WHERE SAFETY_SCORE = (SELECT MAX(SAFETY_SCORE) FROM SCHOOLS)
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Northside Learning Center High School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
#  ('Talman Elementary School', 99),
# ...

# %%
# %sql SELECT * FROM SYSCAT.COLUMNS WHERE TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('QMM86575', 'SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 566, '610543', '609674', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('QMM86575', 'SCHOOLS', 'NAME_OF_SCHOOL', 1, 'SYSIBM  ', 'VARCHAR', 65, 0, 'OCTETS', 65, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'Woodlawn Community Elementary Sch'", "'Abraham Lincoln Elementary School'", 41, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 36, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
    order by Average_Student_Attendance desc nulls last limit 10
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
    order by Average_Student_Attendance \
    fetch first 5 rows only
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# %sql select Name_of_School, REPLACE(Average_Student_Attendance, '%', '') as Average_Student_Attendance from SCHOOLS \
    order by Average_Student_Attendance \
    fetch first 5 rows only
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
    WHERE CAST(REPLACE(Average_Student_Attendance, '%', '') as DOUBLE) < 70 \
    order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from SCHOOLS \
     where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) as COLLEGE_ENROLLMENT \
    FROM SCHOOLS \
    GROUP BY COMMUNITY_AREA_NAME
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
# ...

# %%
# %sql SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) as COLLEGE_ENROLLMENT \
    FROM SCHOOLS \
    GROUP BY COMMUNITY_AREA_NAME \
    order by COLLEGE_ENROLLMENT ASC \
    fetch first 5 rows only
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
##%sql SELECT * FROM SYSCAT.TABLES

# %%
# %sql SELECT * FROM SYSCAT.COLUMNS WHERE TABNAME = 'CHICAGO_SOCIOECONOMIC_DATA'
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('QMM86575', 'CHICAGO_SOCIOECONOMIC_DATA', 'index', 0, 'SYSIBM  ', 'BIGINT', 8, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '76', '1', 9, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('QMM86575', 'CHICAGO_SOCIOECONOMIC_DATA', 'CA', 1, 'SYSIBM  ', 'DOUBLE', 8, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '+7.70000000000000E+001', '+2.00000000000000E+000', 9, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql SELECT CA, HARDSHIP_INDEX FROM CHICAGO_SOCIOECONOMIC_DATA
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(1.0, 39.0),
#  (2.0, 46.0),
#  (3.0, 20.0),
#  (4.0, 17.0),
#  (5.0, 6.0),
#  (6.0, 5.0),
#  (7.0, 2.0),
#  (8.0, 1.0),
#  (9.0, 8.0),
#  (10.0, 21.0),
#  (11.0, 25.0),
#  (12.0, 11.0),
#  (13.0, 33.0),
#  (14.0, 53.0),
#  (15.0, 35.0),
#  (16.0, 34.0),
#  (17.0, 28.0),
#  (18.0, 50.0),
#  (19.0, 70.0),
#  (20.0, 71.0),
#  (21.0, 42.0),
#  (22.0, 23.0),
#  (23.0, 85.0),
#  (24.0, 10.0),
#  (25.0, 73.0),
#  (26.0, 92.0),
#  (27.0, 83.0),
#  (28.0, 15.0),
#  (29.0, 87.0),
#  (30.0, 96.0),
#  (31.0, 76.0),
#  (32.0, 3.0),
#  (33.0, 7.0),
#  (34.0, 82.0),
#  (35.0, 47.0),
#  (36.0, 78.0),
#  (37.0, 97.0),
#  (38.0, 57.0),
#  (39.0, 26.0),
#  (40.0, 88.0),
#  (41.0, 14.0),
#  (42.0, 58.0),
#  (43.0, 55.0),
#  (44.0, 60.0),
#  (45.0, 41.0),
#  (46.0, 75.0),
#  (47.0, 79.0),
#  (48.0, 38.0),
#  (49.0, 52.0),
#  (50.0, 51.0),
#  (51.0, 65.0),
#  (52.0, 64.0),
#  (53.0, 62.0),
# ...

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER FROM SCHOOLS
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(7,),
#  (43,),
#  (70,),
#  (61,),
#  (34,),
#  (14,),
#  (5,),
#  (24,),
#  (5,),
#  (14,),
#  (5,),
#  (61,),
#  (6,),
#  (24,),
#  (49,),
#  (49,),
#  (23,),
#  (72,),
#  (27,),
#  (29,),
#  (48,),
#  (22,),
#  (68,),
#  (24,),
#  (42,),
#  (28,),
#  (67,),
#  (74,),
#  (24,),
#  (38,),
#  (39,),
#  (67,),
#  (46,),
#  (61,),
#  (44,),
#  (17,),
#  (44,),
#  (67,),
#  (70,),
#  (6,),
#  (25,),
#  (42,),
#  (25,),
#  (45,),
#  (75,),
#  (19,),
#  (31,),
#  (68,),
#  (68,),
#  (24,),
#  (40,),
#  (39,),
#  (64,),
#  (41,),
#  (23,),
#  (58,),
#  (38,),
#  (51,),
#  (44,),
#  (58,),
#  (16,),
#  (21,),
#  (68,),
#  (70,),
#  (38,),
#  (61,),
#  (19,),
#  (29,),
#  (70,),
#  (30,),
#  (73,),
#  (41,),
#  (60,),
#  (45,),
#  (19,),
#  (22,),
#  (67,),
#  (69,),
#  (69,),
#  (26,),
#  (67,),
#  (17,),
#  (17,),
#  (74,),
#  (35,),
#  (45,),
#  (9,),
#  (49,),
#  (24,),
#  (71,),
# ...

# %%
# %sql SELECT CA, COMMUNITY_AREA_NAME, HARDSHIP_INDEX FROM CHICAGO_SOCIOECONOMIC_DATA \
    WHERE CA in (select COMMUNITY_AREA_NUMBER FROM SCHOOLS ORDER BY COLLEGE_ENROLLMENT DESC LIMIT 1)
# Out:
#  * ibm_db_sa://qmm86575:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(5.0, 'North Center', 6.0)]
